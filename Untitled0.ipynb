# %% [markdown]
# <a href="https://colab.research.google.com/github/enotnum/halva/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Практическая работа 1. Вяткин И.П. ИБм-22-1

# %%
from keras.datasets import mnist
from matplotlib import pyplot
#loading the dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()
 
#printing the shapes of the vectors 
print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
for i in range(9):  
  pyplot.subplot(330 + 1 + i)
  pyplot.imshow(train_X[i], cmap=pyplot.get_cmap('gray'))
  pyplot.show()

# %%
Var0 = test_X[0:1]
#print(Var0)

Var12 = test_X[11:12]
#print(Var12)

Var146 = test_X[145:146]
#print(Var146)


from matplotlib import pyplot as plt
import numpy as np

def gen_image(arr):
    two_d = (np.reshape(arr, (28, 28)) * 255).astype(np.uint8)
    plt.imshow(two_d, interpolation='nearest')
    return plt
gen_image(test_X[404]).show()
gen_image(test_X[0]).show()
gen_image(test_X[48]).show()
